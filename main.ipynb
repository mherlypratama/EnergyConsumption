# %%
import numpy as np 
import pandas as pd 

import warnings
warnings.filterwarnings("ignore")

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('./data/energy-consumption.csv')

df.head(10)
# Out:
#                     Site Name Department  Year  Current Solar  \
# 0            PHX Building 139   Aviation  2020              0
# 1         Old Verde Park Cntr      Parks  2020              0
# 2  North Ranger Station - Old      Parks  2020              0
# 3  Lookout Mountain Trailhead      Parks  2020              0
# 4                Laveen Basin      Parks  2020              0
# 5              Tawa Mini Park      Parks  2020              0
# 6              Ho-E Mini Park      Parks  2020              0
# 7                PHX Hangar 1   Aviation  2020              0
# 8               Kierland Park      Parks  2020              0
# 9                   Mong Park      Parks  2020              0
#
#   Electric Utility  Electricity Usage  Peak Electric Demand  Building Type   \
# 0              APS                  1                     0  REPAIRSERVICES
# 1              APS                 12                     0         UNKNOWN
# ...

# %%
df.describe()
# Out:
#          Year  Current Solar  Electricity Usage  Peak Electric Demand  \
# count   496.0     496.000000       4.960000e+02            496.000000
# mean   2020.0      18.570565       5.360974e+05            194.112903
# std       0.0     201.573224       3.454466e+06           1115.499161
# min    2020.0       0.000000       1.000000e+00              0.000000
# 25%    2020.0       0.000000       2.823350e+04              0.000000
# 50%    2020.0       0.000000       8.811800e+04             38.000000
# 75%    2020.0       0.000000       2.138845e+05            104.500000
# max    2020.0    4100.000000       6.952790e+07          22957.000000
#
#        Building Area  Natural Gas Usage  Energy Use Intensity    Latitude  \
# count   4.960000e+02         496.000000            280.000000  489.000000
# mean    2.769305e+04        1785.520161             83.157536   33.505784
# std     1.374057e+05       15412.935269            197.958393    0.101549
# ...

# %%
df.isna().sum()
# Out:
# Site Name                 0
# Department                0
# Year                      0
# Current Solar             0
# Electric Utility          0
# Electricity Usage         0
# Peak Electric Demand      0
#  Building Type            0
# Building Area             0
# Natural Gas Usage         0
# Energy Use Intensity    216
# Address                   0
# Latitude                  7
# Longitude                 7
# dtype: int64

# %%
df.shape
# Out:
# (496, 14)

# %% [markdown]
# ## Various locations count

# %%
categoricals = ["Department", "Electric Utility", " Building Type "]
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(20, 6))
for i, j in enumerate(categoricals):
    df[j].value_counts().plot(kind="bar", ax=axes[i])
    for container in axes[i].containers:
        axes[i].bar_label(container, rotation=90)
plt.show()
